# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_json('https://www.mohfw.gov.in/data/datanew.json')
# Reading dataset

# %%
df
# Loading dataset
# Out:
#     sno                                state_name  active  positive     cured  \
# 0     1               Andaman and Nicobar Islands      39     10218     10050
# 1     2                            Andhra Pradesh    1660   2323316   2306925
# 2     3                         Arunachal Pradesh     101     64623     64226
# 3     4                                     Assam    1138    725950    716823
# 4     5                                     Bihar    1574    834542    820706
# 5     6                                Chandigarh     382     94236     92689
# 6     7                              Chhattisgarh    1203   1155495   1140252
# 7     8  Dadra and Nagar Haveli and Daman and Diu      14     11497     11479
# 8     9                                     Delhi    2480   1939227   1910470
# 9    10                                       Goa     799    249565    244925
# 10   11                                   Gujarat    3879   1236071   1221244
# 11   12                                   Haryana    1932   1018742   1006182
# 12   13                          Himachal Pradesh     930    287094    282023
# 13   14                         Jammu and Kashmir     665    455706    450284
# 14   15                                 Jharkhand     468    436384    430595
# 15   16                                 Karnataka    6454   3976053   3929477
# 16   17                                 Kerala***   29772   6663649   6563788
# 17   18                                    Ladakh     125     28543     28190
# 18   19                               Lakshadweep       1     11412     11359
# 19   20                            Madhya Pradesh     788   1045174   1033641
# 20   21                               Maharashtra   19413   7995729   7828352
# 21   22                                   Manipur      97    137367    135150
# 22   23                                 Meghalaya      99     94063     92369
# 23   24                                   Mizoram     497    229609    228406
# 24   25                                  Nagaland      27     35534     34746
# 25   26                                    Odisha    2070   1291946   1280750
# 26   27                                Puducherry     663    167214    164589
# 27   28                                    Punjab    1070    764104    745251
# 28   29                                 Rajasthan     945   1289306   1278791
# 29   30                                    Sikkim      82     39313     38776
# 30   31                                Tamil Nadu   18378   3493599   3437193
# 31   32                                 Telangana    4997    804529    795421
# 32   33                                   Tripura      43    100952     99986
# 33   34                               Uttarakhand     779    439024    430549
# 34   35                             Uttar Pradesh    2225   2092937   2067167
# 35   36                               West Bengal   16546   2042831   2005052
# 36   37                                            122335  43585554  42937876
#
#      death  new_active  new_positive  new_cured  new_death death_reconsille  \
# 0      129          40         10224      10055        129
# 1    14731        1816       2323663    2307116      14731
# 2      296         125         64648      64227        296
# 3     7989        1370        726244     716883       7991
# 4    12262        1742        834964     820960      12262
# 5     1165         375         94299      92759       1165
# 6    14040        1363       1155791    1140388      14040
# 7        4          13         11497      11480          4
# 8    26277        2329       1939758    1911149      26280
# 9     3841         795        249715     245078       3842
# 10   10948        3893       1236707    1221866      10948
# 11   10628        1918       1019095    1006549      10628
# 12    4141        1010        287285     282133       4142
# 13    4757         692        455807     450358       4757
# 14    5321         542        436516     430653       5321
# 15   40122        6506       3977090    3930461      40123
# 16   70107       28891       6666959    6567960      70108               18
# 17     228         125         28555      28202        228
# 18      52           1         11412      11359         52
# 19   10745         778       1045289    1033766      10745
# 20  147964       18851       7998673    7831851     147971
# 21    2120         118        137389     135151       2120
# 22    1595          98         94078      92385       1595
# 23     706         525        229670     228439        706
# 24     761          31         35541      34748        762
# 25    9126        2336       1292416    1280954       9126
# 26    1962         748        167408     164698       1962
# 27   17783        1125        764312     745403      17784
# 28    9570         953       1289443    1278920       9570
# 29     455         101         39342      38785        456
# 30   38028       18687       3496321    3439606      38028
# 31    4111        5146        805137     795880       4111
# 32     923          72        100984      99989        923
# 33    7696         807        439071     430567       7697
# 34   23545        2250       2093310    2067513      23547
# 35   21233       18856       2045781    2005689      21236
# 36  525343      125028      43604394   42953980     525386               18
#
#    total  state_code
# 0                 35
# 1                 28
# 2                 12
# 3      2          18
# 4                 10
# 5                  4
# 6                 22
# 7                 26
# 8      3           7
# 9      1          30
# 10                24
# 11                 6
# 12     1           2
# 13                 1
# 14                20
# 15     1          29
# 16    19          32
# 17                37
# 18                31
# 19                23
# 20     7          27
# 21                14
# 22                17
# 23                15
# 24     1          13
# 25                21
# 26                34
# 27     1           3
# 28                 8
# 29     1          11
# 30                33
# 31                36
# 32                16
# 33     1           5
# 34     2           9
# 35     3          19
# 36    43           0

# %% [markdown]
# ### DataUnderstanding

# %%
df.shape
# There are 37 rows and 11 columns
# Out:
# (37, 13)

# %%
df.isnull().sum()
# no null values
# Out:
# sno                 0
# state_name          0
# active              0
# positive            0
# cured               0
# death               0
# new_active          0
# new_positive        0
# new_cured           0
# new_death           0
# death_reconsille    0
# total               0
# state_code          0
# dtype: int64

# %%
df.info()
# type of data present in the columns(int,object)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   sno               37 non-null     int64
#  1   state_name        37 non-null     object
#  2   active            37 non-null     int64
#  3   positive          37 non-null     int64
#  4   cured             37 non-null     int64
#  5   death             37 non-null     int64
#  6   new_active        37 non-null     int64
#  7   new_positive      37 non-null     int64
#  8   new_cured         37 non-null     int64
#  9   new_death         37 non-null     int64
#  10  death_reconsille  37 non-null     object
#  11  total             37 non-null     object
#  12  state_code        37 non-null     int64
# dtypes: int64(10), object(3)
# memory usage: 3.9+ KB

# %%
df.describe()
# Viewing the descriptive statistics of the data like mean, std deviation, min and max values present in the dataset
# Out:
#              sno         active      positive         cured          death  \
# count  37.000000      37.000000  3.700000e+01  3.700000e+01      37.000000
# mean   19.000000    6612.702703  2.355976e+06  2.320966e+06   28397.405405
# std    10.824355   20640.953944  7.188030e+06  7.080102e+06   88089.146436
# min     1.000000       1.000000  1.021800e+04  1.005000e+04       4.000000
# 25%    10.000000     125.000000  1.009520e+05  9.998600e+04    1165.000000
# 50%    19.000000     930.000000  7.259500e+05  7.168230e+05    7696.000000
# 75%    28.000000    2225.000000  1.291946e+06  1.280750e+06   14731.000000
# max    37.000000  122335.000000  4.358555e+07  4.293788e+07  525343.000000
#
#           new_active  new_positive     new_cured      new_death  state_code
# count      37.000000  3.700000e+01  3.700000e+01      37.000000   37.000000
# mean     6758.270270  2.356994e+06  2.321837e+06   28399.243243   18.324324
# std     21053.777412  7.191138e+06  7.082810e+06   88096.098047   11.212726
# min         1.000000  1.022400e+04  1.005500e+04       4.000000    0.000000
# 25%       125.000000  1.009840e+05  9.998900e+04    1165.000000    9.000000
# 50%       953.000000  7.262440e+05  7.168830e+05    7697.000000   18.000000
# 75%      2329.000000  1.292416e+06  1.280954e+06   14731.000000   28.000000
# max    125028.000000  4.360439e+07  4.295398e+07  525386.000000   37.000000

# %%
df.keys()
# Displaying all the column names present in data
# Out:
# Index(['sno', 'state_name', 'active', 'positive', 'cured', 'death',
#        'new_active', 'new_positive', 'new_cured', 'new_death',
#        'death_reconsille', 'total', 'state_code'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['sno', 'state_name', 'active', 'positive', 'cured', 'death',
#        'new_active', 'new_positive', 'new_cured', 'new_death',
#        'death_reconsille', 'total', 'state_code'],
#       dtype='object')

# %%
df.nunique()
# It returns Series with number of distinct observations.
# Out:
# sno                 37
# state_name          37
# active              37
# positive            37
# cured               37
# death               37
# new_active          36
# new_positive        37
# new_cured           37
# new_death           37
# death_reconsille     2
# total                7
# state_code          37
# dtype: int64

# %%
df.tail()
# As we can see there is an extra row in the end that may be the total of that column
# Out:
#     sno     state_name  active  positive     cured   death  new_active  \
# 32   33        Tripura      43    100952     99986     923          72
# 33   34    Uttarakhand     779    439024    430549    7696         807
# 34   35  Uttar Pradesh    2225   2092937   2067167   23545        2250
# 35   36    West Bengal   16546   2042831   2005052   21233       18856
# 36   37                 122335  43585554  42937876  525343      125028
#
#     new_positive  new_cured  new_death death_reconsille total  state_code
# 32        100984      99989        923                                 16
# 33        439071     430567       7697                      1           5
# 34       2093310    2067513      23547                      2           9
# 35       2045781    2005689      21236                      3          19
# 36      43604394   42953980     525386               18    43           0

# %%
df=df.iloc[:36]
# we apply the iloc function and select all rows except the last row

# %%
df
# Out:
#     sno                                state_name  active  positive    cured  \
# 0     1               Andaman and Nicobar Islands      39     10218    10050
# 1     2                            Andhra Pradesh    1660   2323316  2306925
# 2     3                         Arunachal Pradesh     101     64623    64226
# 3     4                                     Assam    1138    725950   716823
# 4     5                                     Bihar    1574    834542   820706
# 5     6                                Chandigarh     382     94236    92689
# 6     7                              Chhattisgarh    1203   1155495  1140252
# 7     8  Dadra and Nagar Haveli and Daman and Diu      14     11497    11479
# 8     9                                     Delhi    2480   1939227  1910470
# 9    10                                       Goa     799    249565   244925
# 10   11                                   Gujarat    3879   1236071  1221244
# 11   12                                   Haryana    1932   1018742  1006182
# 12   13                          Himachal Pradesh     930    287094   282023
# 13   14                         Jammu and Kashmir     665    455706   450284
# 14   15                                 Jharkhand     468    436384   430595
# 15   16                                 Karnataka    6454   3976053  3929477
# 16   17                                 Kerala***   29772   6663649  6563788
# 17   18                                    Ladakh     125     28543    28190
# 18   19                               Lakshadweep       1     11412    11359
# 19   20                            Madhya Pradesh     788   1045174  1033641
# 20   21                               Maharashtra   19413   7995729  7828352
# 21   22                                   Manipur      97    137367   135150
# 22   23                                 Meghalaya      99     94063    92369
# 23   24                                   Mizoram     497    229609   228406
# 24   25                                  Nagaland      27     35534    34746
# 25   26                                    Odisha    2070   1291946  1280750
# 26   27                                Puducherry     663    167214   164589
# 27   28                                    Punjab    1070    764104   745251
# 28   29                                 Rajasthan     945   1289306  1278791
# 29   30                                    Sikkim      82     39313    38776
# 30   31                                Tamil Nadu   18378   3493599  3437193
# 31   32                                 Telangana    4997    804529   795421
# 32   33                                   Tripura      43    100952    99986
# 33   34                               Uttarakhand     779    439024   430549
# 34   35                             Uttar Pradesh    2225   2092937  2067167
# 35   36                               West Bengal   16546   2042831  2005052
#
#      death  new_active  new_positive  new_cured  new_death death_reconsille  \
# 0      129          40         10224      10055        129
# 1    14731        1816       2323663    2307116      14731
# 2      296         125         64648      64227        296
# 3     7989        1370        726244     716883       7991
# 4    12262        1742        834964     820960      12262
# 5     1165         375         94299      92759       1165
# 6    14040        1363       1155791    1140388      14040
# 7        4          13         11497      11480          4
# 8    26277        2329       1939758    1911149      26280
# 9     3841         795        249715     245078       3842
# 10   10948        3893       1236707    1221866      10948
# 11   10628        1918       1019095    1006549      10628
# 12    4141        1010        287285     282133       4142
# 13    4757         692        455807     450358       4757
# 14    5321         542        436516     430653       5321
# 15   40122        6506       3977090    3930461      40123
# 16   70107       28891       6666959    6567960      70108               18
# 17     228         125         28555      28202        228
# 18      52           1         11412      11359         52
# 19   10745         778       1045289    1033766      10745
# 20  147964       18851       7998673    7831851     147971
# 21    2120         118        137389     135151       2120
# 22    1595          98         94078      92385       1595
# 23     706         525        229670     228439        706
# 24     761          31         35541      34748        762
# 25    9126        2336       1292416    1280954       9126
# 26    1962         748        167408     164698       1962
# 27   17783        1125        764312     745403      17784
# 28    9570         953       1289443    1278920       9570
# 29     455         101         39342      38785        456
# 30   38028       18687       3496321    3439606      38028
# 31    4111        5146        805137     795880       4111
# 32     923          72        100984      99989        923
# 33    7696         807        439071     430567       7697
# 34   23545        2250       2093310    2067513      23547
# 35   21233       18856       2045781    2005689      21236
#
#    total  state_code
# 0                 35
# 1                 28
# 2                 12
# 3      2          18
# 4                 10
# 5                  4
# 6                 22
# 7                 26
# 8      3           7
# 9      1          30
# 10                24
# 11                 6
# 12     1           2
# 13                 1
# 14                20
# 15     1          29
# 16    19          32
# 17                37
# 18                31
# 19                23
# 20     7          27
# 21                14
# 22                17
# 23                15
# 24     1          13
# 25                21
# 26                34
# 27     1           3
# 28                 8
# 29     1          11
# 30                33
# 31                36
# 32                16
# 33     1           5
# 34     2           9
# 35     3          19

# %%
df['active'].sum(axis = 0) 
# The total number of active cases in India is 2,22,526
# Out:
# 122335

# %%
df['positive'].sum(axis = 0) 
# The total number of positive cases in India are 10,466,595
# Out:
# 43585554

# %%
df['cured'].sum(axis = 0)
# The total number of cured cases in India is 10,092,909
# Out:
# 42937876

# %%
df['death'].sum(axis = 0)
# The total number of deaths in India are 1,51,160
# Out:
# 525361

# %%
df['new_active'].sum(axis = 0)
# The total number of new active cases are 2,16,558
# Out:
# 125028

# %%
df['new_positive'].sum(axis = 0)
# The total number of new positive cases are 10,479,179
# Out:
# 43604394

# %%
df['new_cured'].sum(axis = 0)
# The total number of new cured cases are 10,111,294
# Out:
# 42953980

# %%
df['new_death'].sum(axis = 0)
# The total number of new death cases are 1,51,327
# Out:
# 525386

# %% [markdown]
# ### Data Visualization

# %%
sns.pairplot(data=df)
# plotting scatter plots of all data using pairplot

# %%
cases_df=df.sum()
# Storing total cases in cases_df

# %%
cases_df
# Subset of original dataset
# Out:
# sno                                                               666
# state_name          Andaman and Nicobar IslandsAndhra PradeshAruna...
# active                                                         122335
# positive                                                     43585554
# cured                                                        42937876
# death                                                          525361
# new_active                                                     125028
# new_positive                                                 43604394
# new_cured                                                    42953980
# new_death                                                      525386
# death_reconsille                                                   18
# total                                                  23111197111123
# state_code                                                        678
# dtype: object

# %%
cases_df.drop(['sno','state_name','state_code'],inplace=True)
# Dropping unnecessary columns

# %%
cases_df
# Name of case types and their total number
# Out:
# active                      122335
# positive                  43585554
# cured                     42937876
# death                       525361
# new_active                  125028
# new_positive              43604394
# new_cured                 42953980
# new_death                   525386
# death_reconsille                18
# total               23111197111123
# dtype: object

# %%
my_data = [222526,10466595,10092909,151160]
my_labels = 'Active','Positive','Cured','Death'
my_explode = (0,0,0,1.5)
my_colors = ['lightblue','lightsteelblue','lightpink','black']
fig1, ax1 = plt.subplots(figsize=(13, 8))
plt.pie(my_data, labels=my_labels, autopct='%1.1f%%', startangle=15, shadow = True, colors=my_colors, explode=my_explode)
plt.axis('equal')
plt.show()
# Pie chart visualization

# %%
my_data = [216558,10479179,10111294,151327]
my_labels = 'New Active','New Positive','New Cured','New Death'
my_explode = (0,0,0,1.5)
my_colors = ['lightblue','lightsteelblue','lightpink','black']
fig1, ax1 = plt.subplots(figsize=(13, 8))
plt.pie(my_data, labels=my_labels, autopct='%1.1f%%', startangle=15, shadow = True, colors=my_colors, explode=my_explode)
plt.axis('equal')
plt.show()
# Pie chart visualization

# %%
my_data = [222526,10466595,10092909,151160,216558,10479179,10111294,151327]
my_labels = 'Active','Positive','Cured','Death','New Active','New Positive','New Cured','New Death'
my_explode = (0,0,0,0,0,0,0,1.5)
my_colors = ['gray','navajowhite','blanchedalmond','grey','lightblue','papayawhip','moccasin','lightpink']
fig1, ax1 = plt.subplots(figsize=(13, 8))
plt.pie(my_data, labels=my_labels, autopct='%1.1f%%', startangle=15, shadow = True, colors=my_colors, explode=my_explode)
plt.axis('equal')
plt.show()
# Pie chart visualization

# %%
plt.rcParams['figure.figsize']=(13,8)
# giving figure size

# %%
df[['state_name','active']].groupby(["state_name"]).mean().sort_values(by='active').plot.bar(color='purple')
plt.show()
# Kerela has a higher active cases compared to other states

# %%
df[['state_name','death']].groupby(["state_name"]).mean().sort_values(by='death').plot.bar(color='purple')
plt.show()
# Maharashtra has a higher death cases compared to other states

# %%
df.columns
# Displaying column names
# Out:
# Index(['sno', 'state_name', 'active', 'positive', 'cured', 'death',
#        'new_active', 'new_positive', 'new_cured', 'new_death',
#        'death_reconsille', 'total', 'state_code'],
#       dtype='object')

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='active',color='teal',data=df);
# The visualization below shows us that high number of active cases are found in kerala followed by maharashtra

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='positive',color='teal',data=df);
# The below visualization shows us that high number of positive cases can be seen in Maharashtra followed by karnataka

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='cured',color='teal',data=df);
# The visualization below shows us that high number of people have cured in the state of Maharashtra followed by karnataka

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='death',color='teal',data=df);
# The below visualization shows us that high number of deaths taking place in the state of Maharashtra followed by Tamilnadu and karnataka

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='new_active',color='teal',data=df);
# The following visualization shows us the total number of new cases and kerela has the high number of new active cases

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='new_positive',color='teal',data=df);
# The following visualization shows us the total number of new positive cases and Maharashtra has the high number of new positive cases

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='new_cured',color='teal',data=df);
# The following visualization shows us the total number of new cured cases and Maharashtra has the high number of new cured cases

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='new_death',color='teal',data=df);
# Maharashtra has the highest new death rates in India followed by Karnataka

# %%
df.columns
# column names
# Out:
# Index(['sno', 'state_name', 'active', 'positive', 'cured', 'death',
#        'new_active', 'new_positive', 'new_cured', 'new_death',
#        'death_reconsille', 'total', 'state_code'],
#       dtype='object')

# %%
df.drop(['sno','state_code'],axis=1,inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df.head(5)
# This is the resulting data
# Out:
#                     state_name  active  positive    cured  death  new_active  \
# 0  Andaman and Nicobar Islands      39     10218    10050    129          40
# 1               Andhra Pradesh    1660   2323316  2306925  14731        1816
# 2            Arunachal Pradesh     101     64623    64226    296         125
# 3                        Assam    1138    725950   716823   7989        1370
# 4                        Bihar    1574    834542   820706  12262        1742
#
#    new_positive  new_cured  new_death death_reconsille total
# 0         10224      10055        129
# 1       2323663    2307116      14731
# 2         64648      64227        296
# 3        726244     716883       7991                      2
# 4        834964     820960      12262

# %%
df=df.set_index('state_name')
# Setting index as statename

# %%
df.head(5)
# Out:
#                              active  positive    cured  death  new_active  \
# state_name
# Andaman and Nicobar Islands      39     10218    10050    129          40
# Andhra Pradesh                 1660   2323316  2306925  14731        1816
# Arunachal Pradesh               101     64623    64226    296         125
# Assam                          1138    725950   716823   7989        1370
# Bihar                          1574    834542   820706  12262        1742
#
#                              new_positive  new_cured  new_death  \
# state_name
# Andaman and Nicobar Islands         10224      10055        129
# Andhra Pradesh                    2323663    2307116      14731
# Arunachal Pradesh                   64648      64227        296
# Assam                              726244     716883       7991
# Bihar                              834964     820960      12262
#
#                             death_reconsille total
# state_name
# Andaman and Nicobar Islands
# Andhra Pradesh
# Arunachal Pradesh
# Assam                                            2
# Bihar

# %%
df.plot.barh(stacked=True,figsize=(13,8))
# Stacked bar plot

# %%
df1=df[['cured', 'death']] 
df1.plot.barh(color={"cured": "purple", "death": "black"},figsize=(13,8))
# bar plot for cured and death

# %%
df2=df[['positive', 'death']] 
df2.plot.barh(color={"positive": "aquamarine", "death": "orange"},figsize=(13,8))
# bar plot for positive cases and death rate

# %%
df3=df[['death', 'cured']] 
df3.plot.barh(color={"death": "red", "cured": "grey"},figsize=(13,8))
# barplot for death cases and cured cases

# %%
df4=df[['active', 'death']] 
df4.plot.barh(color={"active": "black", "death": "orange"},figsize=(13,8))
# bar plot for active and death cases
